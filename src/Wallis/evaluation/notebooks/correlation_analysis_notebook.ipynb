# %% [markdown]
# ### Notebook to rate by hand sone answers, in order to make correlation analysis

# %%
import json

# %%
with open(
    "./data/intermediate_results/correlation_analysis_data.json", "r"
) as f:
    dico = json.load(f)
i = 0

# %%
with open(
    "./data/intermediate_results/correlation_analysis/user_data.json",
    "r",
) as f:
    dico = json.load(f)
i = 17

# %%
dico["user"][3]

# %%
rating = 5
dico["user"][i]["rating"] = rating
i += 1

# %%
with open(
    "./data/intermediate_results/correlation_analysis/user_data.json",
    "w",
) as f:
    json.dump(dico, f)
